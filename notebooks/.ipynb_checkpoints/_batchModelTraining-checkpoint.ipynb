# %% [markdown]
# ### Logging

# %%
import logging
#logging.getLogger('').handlers = []  #To delete previous logging configuration

logging.basicConfig(
    format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO,
    #If log into standard output and to a file is desired:
    #handlers=[logging.FileHandler("{0}/{1}.log".format('./', uniName)), #path, File name
    #         logging.StreamHandler()]
)

# %% [markdown]
# # Batch Model Training

# %%
import os
#from word2vecTraining import preprocessing, training, evaluation

# Where Text Corpus is located
inputPath = os.path.normpath(r'D:\data\nyt') 
#inputPath = os.path.normpath(r'.') 

# Get all CSV Text Corpus files In target Path
#onlyfiles = [f for f in listdir(inputPath) if isfile(join(inputPath, f)) and f.endswith('.csv')]
#onlyfiles = onlyfiles[:2] #For testing
# print(onlyfiles)
# len(onlyfiles)

#Where output word2vec models will be stored
outputPath = os.path.normpath(r'D:\data\nyt\word2vecModels') #\ to \\
#outputPath = os.path.normpath(r'.\models')

# %% [markdown]
# ## Preprocessing

# %%
import re
import csv
import time
from gensim.parsing.preprocessing import * #provides a number of convenience preprocessing functions optimized for speed
from gensim.models.word2vec import Word2Vec
import gensim
from multiprocessing import cpu_count




def preprocessing(file):

    CUSTOM_FILTERS = [lambda x: x.lower(), #To lowercase
                      lambda text: re.sub(r'https?:\/\/.*\s', '', text, flags=re.MULTILINE), #To Strip away URLs
                      #split_alphanum, #Add spaces between digits & letters in s using RE_AL_NUM.
                      strip_tags, #Remove tags from s using RE_TAGS.
                      strip_non_alphanum,#Remove non-alphabetic characters from s using RE_NONALPHA.
                      strip_punctuation, #Replace punctuation characters with spaces in s using RE_PUNCT.
                      strip_numeric, #Remove digits from s using RE_NUMERIC.
                      strip_multiple_whitespaces,#Remove repeating whitespace characters (spaces, tabs, line breaks) from s and turns tabs & line breaks into spaces using RE_WHITESPACE.
                      remove_stopwords, # Set of 339 stopwords from Stone, Denis, Kwantes (2010).
                      #lambda x:" ".join(w for w in x.split() if w not in stopword_file) #Custom stopwords
                      lambda x: strip_short(x, minsize=3), #Remove words with length lesser than minsize from s.
                      #stem_text #Transform s into lowercase and stem it.
                     ]

    tic = time.time() # Start timing


    csv.field_size_limit(2147483647)
    #csv.field_size_limit(sys.maxsize)
    #Option 1: split paragraphs Into  sentences
    with open(file,'r', newline='',encoding="utf-8") as inpFile:

        csvObject = csv.reader(inpFile, delimiter=',',quotechar='"')

        wordThreshold=5 #Important: filter out sentences with less than wordThreshold words

        sentences = []
        for csvEntry in csvObject:
            if len(csvEntry)>1:
                #IMPORTANT: If all of your sentences have been loaded as one sentence, Word2vec training could take a very long time.
                #That’s because Word2vec is a sentence-level algorithm, so sentence boundaries are very important, because
                #co-occurrence statistics are gathered sentence by sentence. For many corpora, average sentence length is six words.
                #That means that with a window size of 5 you have, say, 30 (random number here) rounds of skip-gram calculations.
                #If you forget to specify your sentence boundaries, you may load a “sentence” that’s 10,000 words long.
                #In that case, Word2vec would attempt a full skip-gram cycle for the whole 10,000-word “sentence”. Hence, I split
                #the CSV entries By paragraphs '\n
                lines = csvEntry[0].split('\n') #csvEntry[0] is url csvEntry[1] is text Fetched from URL

                for line in lines: #Different elements appear in their own line
                    words = preprocess_string(line,CUSTOM_FILTERS)

                    if len(words)>wordThreshold: #Important: filter out sentences with less than wordThreshold words
                        sentences.append(words)

    toc = time.time() # Start timing
    computationTime = toc-tic

    print("Reading Corpus file and preprocessing time:" +str(computationTime)+" seconds")

    print(" printing Top 2 and last sentences For sanity check")
    for i, s in enumerate(sentences[0:2]):
        print(i,s)
    print(len(sentences),sentences[-1])

    print(" stats about Corpus read from file")
    wordsInCorpus = 0
    for i, s in enumerate(sentences):
        wordsInCorpus += len(s)
    print("Number of words in corpus:",wordsInCorpus)
    print("Number of sentences in corpus:",len(sentences))
    #for i, s in enumerate(sentences[0:30]):
    #    print(i,s)
    return sentences

def training(sentences):
    #Training the model
    tic = time.time() # Start timing

    #For the Score method to work hs And negative Parameters need to be specified
    #A good heuristic For Word vectors dimensions `size` thats frequently used is the square-root of the length of the vocabulary, after pre-processing

    model = Word2Vec(sentences, # The sentences iterable can be simply a list of lists of tokens, but for larger corpora, consider an iterable that streams the sentences directly from disk/network
                     sg=0, #Defines the training algorithm. If 1, skip-gram is employed; otherwise, CBOW is used
                     size=300,#Dimensionality of the feature vectors
                     window=10,# The maximum distance between the current and predicted word within a sentence
                     min_count=5, #Ignores all words with total frequency lower than this
                     workers=cpu_count()-3, #Use these many worker threads to train the model (=faster training with multicore machines).
                     hs = 0, # int {1,0}) – If 1, hierarchical softmax will be used for model training. If set to 0, and negative is non-zero, negative sampling will be used.
                     negative = 10, # If > 0, negative sampling will be used, specifies how many “noise words” should be drawn (usually between 5-20). If set to 0, no negative sampling is used.
                     sample = 0.001, # The threshold for configuring which higher-frequency words are randomly downsampled, useful range is (0, 1e-5).
                     iter = 5, # (int) – Number of iterations (epochs) over the corpus. //5
                    )

    toc = time.time() # Start timing
    computationTime = toc-tic
    print("Computing time for training the model:" +str(computationTime)+" seconds")
    wordsInCorpus = sum([len(l) for l in sentences])
    print("Number of words processed per second:",wordsInCorpus/computationTime)
    print(model)
    print("Most frequent words In model: ", model.wv.index2word[:10])

    return model
# Out:
# c:\python3\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# 2018-10-15 11:46:11,511 : INFO : 'pattern' package not found; tag filters are not available for English

# %%
years = ['1999','1998','1997','1996','1995','1994','1993','1992','1991','1990','1989','1988','1987','1986','1985']

for year in years: 
    print("starting the processing of " + year)
    inputFilePath = os.path.join(inputPath, year+'.csv')
    sentences = preprocessing(inputFilePath)
    model = training(sentences)
    #Discard parameters that are used in training and score. Use if you’re sure you’re done training a model.
    #If replace_word_vectors_with_normalized is set, forget the original vectors and only keep 
    #the normalized ones = saves lots of memory!
    model.delete_temporary_training_data(replace_word_vectors_with_normalized=False)   
    # Evaluation
    print(" similarity evaluation:", model.wv.evaluate_word_pairs('wordsim353.tsv', restrict_vocab=50000))
    # Analogies
    r = model.wv.accuracy('questions-words.txt', restrict_vocab=30000)
    outputFilePath = os.path.join(outputPath, year)
    model.save(outputFilePath) #binary=False saves the vectors as Textual data
    print("----------------------------------------------------")
# Out:
# starting the processing of 1999
# Reading Corpus file and preprocessing time:68.53386998176575 seconds
#  printing Top 2 and last sentences For sanity check
# 0 ['years', 'ago', 'american', 'company', 'seeking', 'toehold', 'newly', 'privatized', 'potentially', 'lucrative', 'russian', 'telecommunications', 'market', 'cut', 'secret', 'deal', 'directors', 'officers', 'moscow', 'telephone', 'company', 'arrangement', 'raised', 'legal', 'ethical', 'questions', 'thrown', 'light', 'western', 'businessmen', 'operated', 'russia', 'american', 'company', 'global', 'telesystems', 'paid', 'million', 'stock', 'cash', 'global', 'paid', 'money', 'company', 'insiders', 'set', 'bahamas', 'avoid', 'public', 'scrutiny', 'taxes', 'exchange', 'global', 'telesystems', 'ended', 'ownership', 'russian', 'telecommunications', 'company', 'generates', 'millions', 'dollars', 'year', 'revenues', 'providing', 'service', 'moscow', 'customers', 'businesses', 'willing', 'pay', 'premium', 'russians', 'took', 'deal', 'walked', 'away', 'million', 'cash', 'stock', 'tax', 'free', 'russian', 'government', 'says', 'phone', 'company', 'insiders', 'committed', 'fraud', 'tax', 'evasion', 'opened', 'investigation', 'law', 'enforcement', 'agencies', 'countries', 'insiders', 'stashed', 'gains', 'global', 'telesystems', 'fast', 'growing', 'company', 'based', 'mclean', 'says', 'transaction', 'broke', 'russian', 'american', 'laws', 'global', 'telesystems', 'deal', 'illustrates', 'western', 'business', 'maneuvers', 'undermine', 'western', 'governments', 'efforts', 'promote', 'russia', 'economic', 'transformation', 'western', 'business', 'political', 'leaders', 'lectured', 'russians', 'saying', 'want', 'attract', 'foreign', 'investment', 'adopt', 'laws', 'protect', 'shareholders', 'rights', 'improve', 'tax', 'collection', 'global', 'telesystems', 'deal', 'resulted', 'moscow', 'phone', 'company', 'defrauded', 'million', 'based', 'value', 'phone', 'lines', 'projected', 'revenues', 'according', 'russian', 'ministry', 'interior', 'western', 'investigators', 'shareholders', 'company', 'moscow', 'city', 'telephone', 'network', 'include', 'russian', 'government', 'handful', 'investors', 'united', 'states', 'stock', 'traded', 'america', 'insiders', 'dealings', 'provoke', 'shareholder', 'lawsuits', 'corporate', 'securities', 'law', 'experts', 'unlikely', 'russia', 'illegal', 'question', 'ethical', 'smart', 'said', 'jonathan', 'winer', 'monitored', 'money', 'laundering', 'international', 'activities', 'deputy', 'assistant', 'secretary', 'state', 'stepping', 'recently', 'american', 'investment', 'banker', 'moscow', 'described', 'global', 'deal', 'tip', 'iceberg', 'example', 'western', 'companies', 'engaged', 'business', 'practices', 'russia', 'try', 'home', 'cases', 'executives', 'said', 'remain', 'carefully', 'guarded', 'corporate', 'secrets', 'details', 'arrangement', 'global', 'telesystems', 'phone', 'company', 'insiders', 'emerge', 'documents', 'filed', 'global', 'telesystems', 'securities', 'exchange', 'commission', 'information', 'company', 'insiders', 'gathered', 'law', 'enforcement', 'officials', 'united', 'states', 'russia', 'europe', 'global', 'telesystems', 'positioned', 'opportunities', 'offered', 'new', 'russia', 'privatization', 'moscow', 'city', 'telephone', 'american', 'company', 'worked', 'old', 'communist', 'soviet', 'union', 'early', 'company', 'based', 'california', 'called', 'san', 'francisco', 'moscow', 'teleport', 'changed', 'global', 'telesystems', 'issued', 'stock', 'publicly', 'years', 'later', 'million', 'initial', 'offering', 'months', 'ago', 'global', 'telesystems', 'russian', 'eastern', 'european', 'operations', 'subsidiary', 'golden', 'telecom', 'sold', 'percent', 'initial', 'public', 'offering', 'raised', 'million', 'global', 'biggest', 'backers', 'early', 'days', 'george', 'soros', 'international', 'financier', 'active', 'commercially', 'philanthropically', 'soviet', 'union', 'years', 'ago', 'soros', 'affiliate', 'companies', 'owned', 'percent', 'global', 'telesystems', 'according', 'company', 'filing', 'played', 'management', 'role', 'company', 'stake', 'company', 'percent', 'spokesman', 'soros', 'said', 'larger' ...
# 1 ['new', 'york', 'city', 'school', 'patient', 'racing', 'highly', 'recommended', 'doctor', 'getting', 'better', 'finally', 'hey', 'wait', 'minute', 'maybe', 'diagnosis', 'wrong', 'prevailing', 'diagnosis', 'ails', 'city', 'school', 'large', 'disjointed', 'unaccountable', 'mayor', 'needs', 'control', 'board', 'education', 'undistinguished', 'bureaucracy', 'large', 'teachers', 'union', 'powerful', 'true', 'leaders', 'urban', 'school', 'districts', 'country', 'average', 'half', 'years', 'cities', 'different', 'systems', 'mayors', 'different', 'powers', 'problems', 'resemble', 'new', 'york', 'topples', 'decent', 'committed', 'educators', 'like', 'joseph', 'fernandez', 'ray', 'cortines', 'rudy', 'crew', 'systemic', 'flaws', 'symptoms', 'fundamental', 'signs', 'point', 'direction', 'economic', 'social', 'realities', 'uncomfortable', 'face', 'head', 'confront', 'consequences', 'middle', 'class', 'flight', 'public', 'schools', 'children', 'schools', 'overwhelmingly', 'black', 'hispanic', 'parents', 'work', 'jobs', 'time', 'apply', 'political', 'pressure', 'schools', 'mayor', 'organized', 'sway', 'elections', 'lack', 'money', 'buy', 'political', 'access', 'influence', 'campaign', 'contributions', 'powerful', 'people', 'new', 'york', 'cities', 'politicians', 'business', 'executives', 'yes', 'journalists', 'send', 'children', 'public', 'schools', 'profound', 'impact', 'new', 'yorkers', 'pick', 'phone', 'city', 'hall', 'literally', 'leaking', 'roofs', 'computerless', 'classrooms', 'revolving', 'chancellors', 'elected', 'officials', 'respond', 'power', 'influence', 'parents', 'schoolchildren', 'decentralization', 'solution', 'remaining', 'hope', 'economic', 'necessity', 'force', 'power', 'elite', 'care', 'schools', 'children', 'longer', 'attend', 'realization', 'educated', 'work', 'force', 'country', 'competitive', 'leads', 'fundamental', 'problem', 'figured', 'best', 'educate', 'largely', 'poor', 'children', 'prepared', 'motivated', 'students', 'past', 'generations', 'right', 'reform', 'country', 'centers', 'setting', 'impossibly', 'high', 'standards', 'putting', 'obsessive', 'emphasis', 'test', 'results', 'criticizing', 'teachers', 'administrators', 'achieving', 'great', 'results', 'overnight', 'teachers', 'cheat', 'students', 'fail', 'educators', 'beginning', 'acknowledge', 'programming', 'millions', 'children', 'failure', 'setting', 'single', 'standard', 'makes', 'sense', 'want', 'reform', 'reform', 'phasing', 'higher', 'standards', 'gradually', 'recognizing', 'raising', 'bar', 'high', 'students', 'intensive', 'instruction', 'preschool', 'classes', 'require', 'longer', 'school', 'days', 'year', 'round', 'ensure', 'smaller', 'classes', 'greater', 'resources', 'especially', 'pay', 'teachers', 'crew', 'instituted', 'mandatory', 'summer', 'school', 'sensible', 'things', 'happening', 'overshadowed', 'mania', 'test', 'scores', 'national', 'standards', 'persistent', 'search', 'alternatives', 'public', 'education', 'figured', 'educate', 'children', 'public', 'schools', 'hard', 'believe', 'mayor', 'rudolph', 'giuliani', 'succumbed', 'political', 'pressure', 'experiment', 'vouchers', 'defensive', 'political', 'precipitated', 'breach', 'crew', 'city', 'second', 'black', 'chancellor', 'saw', 'mayor', 'proposal', 'betrayal', 'public', 'education', 'particularly', 'mission', 'educating', 'black', 'hispanic', 'children', 'turn', 'controversy', 'comes', 'issue', 'finding', 'effective', 'realistic', 'ways', 'educate', 'today', 'students', 'yes', 'makes', 'sense', 'politicians', 'appointing', 'seven', 'members', 'board', 'education', 'need', 'direct', 'accountability', 'distinguished', 'board', 'members', 'let', 'mayor', 'officially', 'unofficially', 'direct', 'control', 'direct', 'responsibility', 'failings', 'let', 'weaken', 'union', 'driven', 'rules', 'protect', 'mediocrity', 'new', 'year', 'prediction', 'bitter', 'comings', 'goings', 'chancellors', 'continue', 'country', 'acknowledges', 'problem', 'fundamental', 'structure']
# 82892 ['time', 'probably', 'fair', 'mccourt', 'family', 'limerick', 'manhattan', 'known', 'irish', 'family', 'new', 'world', 'couple', 'years', 'surviving', 'children', 'angela', 'malachy', 'mccourt', 'produced', 'best', 'selling', 'memoirs', 'frank', 'angela', 'ashes', 'malachy', 'monk', 'swimming', 'featured', 'hbo', 'television', 'documentary', 'mccourts', 'limerick', 'produced', 'malachy', 'son', 'conor', 'told', 'course', 'malachy', 'says', 'brief', 'career', 'television', 'host', 'couldn', 'wait', 'hear', 'conor', 'mccourt', 'brought', 'brothers', 'frank', 'malachy', 'mike', 'alphie', 'mccourts', 'new', 'york', 'hourlong', 'string', 'anecdote', 'reminiscence', 'boys', 'poor', 'sodden', 'irish', 'city', 'came', 'age', 'crucible', 'manhattan', 'broadcast', 'hbo', 'tuesday', 'day', 'patrick', 'day', 'know', 'frank', 'mccourt', 'english', 'teacher', 'says', 'early', 'revisits', 'west', 'warehouses', 'boat', 'laboring', 'jobs', 'going', 'stuff', 'people', 'content', 'let', 'answer', 'comes', 'malachy', 'new', 'york', 'police', 'sergeant', 'named', 'conor', 'keeps', 'asking', 'questions', 'till', 'exhaust', 'memory', 'yes', 'malachy', 'fault', 'passed', 'storytelling', 'gene', 'conor', 'dropout', 'new', 'york', 'university', 'film', 'school', 'day', 'job', 'actually', 'midnight', 'patrol', 'supervisor', 'manhattan', 'midtown', 'north', 'precinct', 'wife', 'juliet', 'conor', 'mccourt', 'spends', 'free', 'time', 'making', 'films', 'things', 'know', 'surely', 'knows', 'mccourts', 'films', 'good', 'natured', 'caveat', 'finished', 'mccourts', 'says', 'preparing', 'documentary', 'police', 'officers', 'adam', 'apple', 'mccourts', 'mccourts', 'ingratiating', 'persistent', 'finished', 'survived', 'abandonment', 'alcoholic', 'father', 'poverty', 'limerick', 'rough', 'tumble', 'postwar', 'america', 'wisdom', 'bitterness', 'articulate', 'stand', 'ins', 'family', 'left', 'old', 'country', 'come', 'frank', 'eldest', 'came', 'malachy', 'mike', 'alphie', 'years', 'younger', 'frank', 'like', 'prisoners', 'fashioning', 'serial', 'escape', 'threw', 'lifeline', 'frank', 'sent', 'home', 'malachy', 'arrived', 'ship', 'soon', 'got', 'job', 'welfare', 'island', 'gave', 'white', 'jacket', 'white', 'cap', 'white', 'trousers', 'white', 'shoes', 'said', 'thought', 'going', 'bloody', 'surgeon', 'instead', 'dishwasher', 'general', 'cleanup', 'sort', 'guy', 'heart', 'malachy', 'career', 'raconteur', 'occasional', 'television', 'celebrity', 'grew', 'proprietorship', 'saloon', 'country', 'upper', 'east', 'mike', 'recall', 'days', 'dispensers', 'whisky', 'good', 'smell', 'stale', 'beer', 'barroom', 'doorways', 'morning', 'avenue', 'womblike', 'quality', 'malachy', 'says', 'speaking', 'welcoming', 'bars', 'blarney', 'killarney', 'mcthis', 'windows', 'lit', 'green', 'neon', 'shamrocks', 'closure', 'tale', 'comes', 'end', 'film', 'moment', 'commemoration', 'knew', 'sister', 'margaret', 'mary', 'died', 'shortly', 'birth', 'having', 'child', 'die', 'monstrous', 'alphie', 'says', 'speaks', 'mother', 'know', 'smiled', 'laughed', 'search', 'margaret', 'mary', 'ended', 'queens', 'cemetery', 'mass', 'grave', 'poor', 'children', 'monument', 'affixed', 'plaque', 'sister', 'anonymous', 'frank', 'says', 'putting', 'ointment', 'souls', 'mike', 'says', 'nice', 'big', 'sister', 'alphie', 'says', 'better', 'dancers']
#  stats about Corpus read from file
# Number of words in corpus: 26087311
# Number of sentences in corpus: 82892
# 2018-10-15 12:50:04,951 : INFO : collecting all words and their counts
# 2018-10-15 12:50:04,952 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-10-15 12:50:05,508 : INFO : PROGRESS: at sentence #10000, processed 3297755 words, keeping 94810 word types
# 2018-10-15 12:50:06,053 : INFO : PROGRESS: at sentence #20000, processed 6440084 words, keeping 124716 word types
# 2018-10-15 12:50:06,584 : INFO : PROGRESS: at sentence #30000, processed 9518989 words, keeping 153234 word types
# 2018-10-15 12:50:07,146 : INFO : PROGRESS: at sentence #40000, processed 12663848 words, keeping 174160 word types
# 2018-10-15 12:50:07,733 : INFO : PROGRESS: at sentence #50000, processed 15803772 words, keeping 194587 word types
# 2018-10-15 12:50:08,292 : INFO : PROGRESS: at sentence #60000, processed 18886648 words, keeping 209957 word types
# 2018-10-15 12:50:08,863 : INFO : PROGRESS: at sentence #70000, processed 22040075 words, keeping 224773 word types
# 2018-10-15 12:50:09,429 : INFO : PROGRESS: at sentence #80000, processed 25149852 words, keeping 238119 word types
# 2018-10-15 12:50:09,596 : INFO : collected 241699 word types from a corpus of 26087311 raw words and 82892 sentences
# 2018-10-15 12:50:09,597 : INFO : Loading a fresh vocabulary
# 2018-10-15 12:50:10,840 : INFO : effective_min_count=5 retains 95145 unique words (39% of original 241699, drops 146554)
# 2018-10-15 12:50:10,841 : INFO : effective_min_count=5 leaves 25843306 word corpus (99% of original 26087311, drops 244005)
# 2018-10-15 12:50:11,066 : INFO : deleting the raw counts dictionary of 241699 items
# 2018-10-15 12:50:11,074 : INFO : sample=0.001 downsamples 7 most-common words
# 2018-10-15 12:50:11,075 : INFO : downsampling leaves estimated 25464417 word corpus (98.5% of prior 25843306)
# 2018-10-15 12:50:11,420 : INFO : estimated required memory for 95145 words and 300 dimensions: 275920500 bytes
# 2018-10-15 12:50:11,421 : INFO : resetting layer weights
# 2018-10-15 12:50:12,330 : INFO : training model with 13 workers on 95145 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=10 window=10
# 2018-10-15 12:50:13,340 : INFO : EPOCH 1 - PROGRESS: at 4.57% examples, 1182141 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:50:14,348 : INFO : EPOCH 1 - PROGRESS: at 9.19% examples, 1224799 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:50:15,350 : INFO : EPOCH 1 - PROGRESS: at 14.05% examples, 1238317 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:50:16,352 : INFO : EPOCH 1 - PROGRESS: at 18.97% examples, 1243961 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:50:17,360 : INFO : EPOCH 1 - PROGRESS: at 24.10% examples, 1249378 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:50:18,364 : INFO : EPOCH 1 - PROGRESS: at 29.43% examples, 1250885 words/s, in_qsize 26, out_qsize 2
# 2018-10-15 12:50:19,365 : INFO : EPOCH 1 - PROGRESS: at 34.09% examples, 1249114 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:50:20,371 : INFO : EPOCH 1 - PROGRESS: at 39.05% examples, 1250154 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:50:21,374 : INFO : EPOCH 1 - PROGRESS: at 44.14% examples, 1251817 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:50:22,378 : INFO : EPOCH 1 - PROGRESS: at 48.92% examples, 1249325 words/s, in_qsize 22, out_qsize 3
# 2018-10-15 12:50:23,383 : INFO : EPOCH 1 - PROGRESS: at 53.85% examples, 1251540 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:50:24,395 : INFO : EPOCH 1 - PROGRESS: at 58.99% examples, 1250219 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:50:25,415 : INFO : EPOCH 1 - PROGRESS: at 64.15% examples, 1250894 words/s, in_qsize 25, out_qsize 2
# 2018-10-15 12:50:26,424 : INFO : EPOCH 1 - PROGRESS: at 69.16% examples, 1250897 words/s, in_qsize 25, out_qsize 1
# 2018-10-15 12:50:27,435 : INFO : EPOCH 1 - PROGRESS: at 74.22% examples, 1250523 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:50:28,454 : INFO : EPOCH 1 - PROGRESS: at 79.25% examples, 1251579 words/s, in_qsize 22, out_qsize 3
# 2018-10-15 12:50:29,464 : INFO : EPOCH 1 - PROGRESS: at 84.24% examples, 1252544 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:50:30,478 : INFO : EPOCH 1 - PROGRESS: at 89.25% examples, 1252847 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:50:31,478 : INFO : EPOCH 1 - PROGRESS: at 94.23% examples, 1253133 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:50:32,477 : INFO : EPOCH 1 - PROGRESS: at 99.09% examples, 1252856 words/s, in_qsize 23, out_qsize 0
# 2018-10-15 12:50:32,550 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2018-10-15 12:50:32,576 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2018-10-15 12:50:32,578 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2018-10-15 12:50:32,581 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2018-10-15 12:50:32,595 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2018-10-15 12:50:32,600 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2018-10-15 12:50:32,603 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2018-10-15 12:50:32,611 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-10-15 12:50:32,616 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-10-15 12:50:32,618 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-15 12:50:32,619 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-15 12:50:32,620 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-15 12:50:32,624 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-15 12:50:32,624 : INFO : EPOCH - 1 : training on 26087311 raw words (25452865 effective words) took 20.3s, 1254490 effective words/s
# 2018-10-15 12:50:33,634 : INFO : EPOCH 2 - PROGRESS: at 4.62% examples, 1201009 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:50:34,637 : INFO : EPOCH 2 - PROGRESS: at 9.15% examples, 1219187 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:50:35,655 : INFO : EPOCH 2 - PROGRESS: at 14.05% examples, 1233604 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:50:36,677 : INFO : EPOCH 2 - PROGRESS: at 19.15% examples, 1243795 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:50:37,686 : INFO : EPOCH 2 - PROGRESS: at 24.28% examples, 1248786 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:50:38,693 : INFO : EPOCH 2 - PROGRESS: at 29.65% examples, 1252807 words/s, in_qsize 26, out_qsize 1
# 2018-10-15 12:50:39,695 : INFO : EPOCH 2 - PROGRESS: at 34.48% examples, 1256199 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:50:40,701 : INFO : EPOCH 2 - PROGRESS: at 39.43% examples, 1257227 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:50:41,706 : INFO : EPOCH 2 - PROGRESS: at 44.39% examples, 1253967 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:50:42,715 : INFO : EPOCH 2 - PROGRESS: at 49.44% examples, 1255175 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:50:43,726 : INFO : EPOCH 2 - PROGRESS: at 54.29% examples, 1256017 words/s, in_qsize 26, out_qsize 2
# 2018-10-15 12:50:44,748 : INFO : EPOCH 2 - PROGRESS: at 59.61% examples, 1257449 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:50:45,754 : INFO : EPOCH 2 - PROGRESS: at 64.75% examples, 1257641 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:50:46,769 : INFO : EPOCH 2 - PROGRESS: at 69.90% examples, 1258979 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:50:47,777 : INFO : EPOCH 2 - PROGRESS: at 74.87% examples, 1257701 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:50:48,785 : INFO : EPOCH 2 - PROGRESS: at 79.86% examples, 1258649 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:50:49,803 : INFO : EPOCH 2 - PROGRESS: at 84.80% examples, 1257524 words/s, in_qsize 26, out_qsize 2
# 2018-10-15 12:50:50,810 : INFO : EPOCH 2 - PROGRESS: at 89.93% examples, 1259009 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:50:51,829 : INFO : EPOCH 2 - PROGRESS: at 95.00% examples, 1258734 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:50:52,760 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2018-10-15 12:50:52,776 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2018-10-15 12:50:52,777 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2018-10-15 12:50:52,781 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2018-10-15 12:50:52,797 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2018-10-15 12:50:52,798 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2018-10-15 12:50:52,799 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2018-10-15 12:50:52,802 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-10-15 12:50:52,815 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-10-15 12:50:52,819 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-15 12:50:52,821 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-15 12:50:52,823 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-15 12:50:52,830 : INFO : EPOCH 2 - PROGRESS: at 100.00% examples, 1259909 words/s, in_qsize 0, out_qsize 1
# 2018-10-15 12:50:52,831 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-15 12:50:52,832 : INFO : EPOCH - 2 : training on 26087311 raw words (25452355 effective words) took 20.2s, 1259822 effective words/s
# 2018-10-15 12:50:53,841 : INFO : EPOCH 3 - PROGRESS: at 4.62% examples, 1201004 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:50:54,859 : INFO : EPOCH 3 - PROGRESS: at 9.22% examples, 1223359 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:50:55,869 : INFO : EPOCH 3 - PROGRESS: at 14.16% examples, 1240322 words/s, in_qsize 22, out_qsize 3
# 2018-10-15 12:50:56,881 : INFO : EPOCH 3 - PROGRESS: at 19.18% examples, 1246967 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:50:57,883 : INFO : EPOCH 3 - PROGRESS: at 24.24% examples, 1249564 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:50:58,891 : INFO : EPOCH 3 - PROGRESS: at 29.68% examples, 1256298 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:50:59,895 : INFO : EPOCH 3 - PROGRESS: at 34.47% examples, 1257446 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:51:00,918 : INFO : EPOCH 3 - PROGRESS: at 39.52% examples, 1258124 words/s, in_qsize 26, out_qsize 2
# 2018-10-15 12:51:01,921 : INFO : EPOCH 3 - PROGRESS: at 44.64% examples, 1259017 words/s, in_qsize 26, out_qsize 1
# 2018-10-15 12:51:02,950 : INFO : EPOCH 3 - PROGRESS: at 49.66% examples, 1258255 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:51:03,958 : INFO : EPOCH 3 - PROGRESS: at 54.49% examples, 1258378 words/s, in_qsize 22, out_qsize 3
# 2018-10-15 12:51:04,979 : INFO : EPOCH 3 - PROGRESS: at 59.78% examples, 1258814 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:51:05,987 : INFO : EPOCH 3 - PROGRESS: at 65.02% examples, 1260151 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:51:06,991 : INFO : EPOCH 3 - PROGRESS: at 69.88% examples, 1257693 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:51:07,995 : INFO : EPOCH 3 - PROGRESS: at 75.01% examples, 1258575 words/s, in_qsize 26, out_qsize 1
# 2018-10-15 12:51:09,001 : INFO : EPOCH 3 - PROGRESS: at 79.95% examples, 1259078 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:51:10,002 : INFO : EPOCH 3 - PROGRESS: at 84.79% examples, 1258139 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:51:11,003 : INFO : EPOCH 3 - PROGRESS: at 89.89% examples, 1259404 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:51:12,021 : INFO : EPOCH 3 - PROGRESS: at 94.92% examples, 1258745 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:51:12,984 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2018-10-15 12:51:12,998 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2018-10-15 12:51:12,999 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2018-10-15 12:51:13,000 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2018-10-15 12:51:13,001 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2018-10-15 12:51:13,022 : INFO : EPOCH 3 - PROGRESS: at 99.76% examples, 1257688 words/s, in_qsize 7, out_qsize 1
# 2018-10-15 12:51:13,023 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2018-10-15 12:51:13,023 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2018-10-15 12:51:13,030 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-10-15 12:51:13,033 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-10-15 12:51:13,041 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-15 12:51:13,042 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-15 12:51:13,045 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-15 12:51:13,051 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-15 12:51:13,051 : INFO : EPOCH - 3 : training on 26087311 raw words (25451591 effective words) took 20.2s, 1259006 effective words/s
# 2018-10-15 12:51:14,068 : INFO : EPOCH 4 - PROGRESS: at 4.60% examples, 1183449 words/s, in_qsize 26, out_qsize 1
# 2018-10-15 12:51:15,076 : INFO : EPOCH 4 - PROGRESS: at 9.19% examples, 1220436 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:51:16,082 : INFO : EPOCH 4 - PROGRESS: at 14.10% examples, 1236759 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:51:17,093 : INFO : EPOCH 4 - PROGRESS: at 19.10% examples, 1244607 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:51:18,104 : INFO : EPOCH 4 - PROGRESS: at 24.07% examples, 1241360 words/s, in_qsize 26, out_qsize 0
# 2018-10-15 12:51:19,109 : INFO : EPOCH 4 - PROGRESS: at 29.49% examples, 1248839 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:51:20,111 : INFO : EPOCH 4 - PROGRESS: at 34.17% examples, 1247344 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:51:21,128 : INFO : EPOCH 4 - PROGRESS: at 39.13% examples, 1247836 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:51:22,138 : INFO : EPOCH 4 - PROGRESS: at 44.30% examples, 1250105 words/s, in_qsize 25, out_qsize 2
# 2018-10-15 12:51:23,142 : INFO : EPOCH 4 - PROGRESS: at 49.31% examples, 1252372 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:51:24,160 : INFO : EPOCH 4 - PROGRESS: at 54.07% examples, 1250115 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:51:25,178 : INFO : EPOCH 4 - PROGRESS: at 59.28% examples, 1250041 words/s, in_qsize 26, out_qsize 1
# 2018-10-15 12:51:26,190 : INFO : EPOCH 4 - PROGRESS: at 64.38% examples, 1250193 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:51:27,198 : INFO : EPOCH 4 - PROGRESS: at 69.35% examples, 1249613 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:51:28,207 : INFO : EPOCH 4 - PROGRESS: at 74.45% examples, 1250467 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:51:29,208 : INFO : EPOCH 4 - PROGRESS: at 79.33% examples, 1250212 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:51:30,215 : INFO : EPOCH 4 - PROGRESS: at 84.15% examples, 1248684 words/s, in_qsize 26, out_qsize 1
# 2018-10-15 12:51:31,217 : INFO : EPOCH 4 - PROGRESS: at 89.03% examples, 1248947 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:51:32,228 : INFO : EPOCH 4 - PROGRESS: at 94.02% examples, 1248724 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:51:33,231 : INFO : EPOCH 4 - PROGRESS: at 98.95% examples, 1248874 words/s, in_qsize 25, out_qsize 2
# 2018-10-15 12:51:33,333 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2018-10-15 12:51:33,351 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2018-10-15 12:51:33,354 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2018-10-15 12:51:33,356 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2018-10-15 12:51:33,372 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2018-10-15 12:51:33,376 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2018-10-15 12:51:33,377 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2018-10-15 12:51:33,382 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-10-15 12:51:33,387 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-10-15 12:51:33,397 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-15 12:51:33,399 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-15 12:51:33,402 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-15 12:51:33,403 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-15 12:51:33,403 : INFO : EPOCH - 4 : training on 26087311 raw words (25452160 effective words) took 20.3s, 1250824 effective words/s
# 2018-10-15 12:51:34,426 : INFO : EPOCH 5 - PROGRESS: at 4.64% examples, 1196770 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:51:35,427 : INFO : EPOCH 5 - PROGRESS: at 9.19% examples, 1221757 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:51:36,435 : INFO : EPOCH 5 - PROGRESS: at 14.10% examples, 1236528 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:51:37,445 : INFO : EPOCH 5 - PROGRESS: at 18.97% examples, 1238239 words/s, in_qsize 22, out_qsize 3
# 2018-10-15 12:51:38,452 : INFO : EPOCH 5 - PROGRESS: at 24.04% examples, 1240793 words/s, in_qsize 26, out_qsize 3
# 2018-10-15 12:51:39,459 : INFO : EPOCH 5 - PROGRESS: at 29.43% examples, 1246228 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:51:40,468 : INFO : EPOCH 5 - PROGRESS: at 34.17% examples, 1246777 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:51:41,479 : INFO : EPOCH 5 - PROGRESS: at 39.09% examples, 1245912 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:51:42,492 : INFO : EPOCH 5 - PROGRESS: at 44.10% examples, 1244631 words/s, in_qsize 22, out_qsize 3
# 2018-10-15 12:51:43,503 : INFO : EPOCH 5 - PROGRESS: at 49.04% examples, 1245565 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:51:44,514 : INFO : EPOCH 5 - PROGRESS: at 53.99% examples, 1248301 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:51:45,533 : INFO : EPOCH 5 - PROGRESS: at 59.17% examples, 1247394 words/s, in_qsize 26, out_qsize 1
# 2018-10-15 12:51:46,546 : INFO : EPOCH 5 - PROGRESS: at 64.24% examples, 1247560 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:51:47,550 : INFO : EPOCH 5 - PROGRESS: at 69.16% examples, 1246325 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:51:48,551 : INFO : EPOCH 5 - PROGRESS: at 73.86% examples, 1241334 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:51:49,564 : INFO : EPOCH 5 - PROGRESS: at 78.75% examples, 1240926 words/s, in_qsize 26, out_qsize 0
# 2018-10-15 12:51:50,571 : INFO : EPOCH 5 - PROGRESS: at 83.70% examples, 1241214 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:51:51,588 : INFO : EPOCH 5 - PROGRESS: at 88.55% examples, 1240863 words/s, in_qsize 26, out_qsize 3
# 2018-10-15 12:51:52,607 : INFO : EPOCH 5 - PROGRESS: at 93.63% examples, 1241197 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:51:53,610 : INFO : EPOCH 5 - PROGRESS: at 98.55% examples, 1241645 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:51:53,809 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2018-10-15 12:51:53,825 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2018-10-15 12:51:53,834 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2018-10-15 12:51:53,836 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2018-10-15 12:51:53,837 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2018-10-15 12:51:53,840 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2018-10-15 12:51:53,855 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2018-10-15 12:51:53,859 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-10-15 12:51:53,863 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-10-15 12:51:53,874 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-15 12:51:53,879 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-15 12:51:53,880 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-15 12:51:53,881 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-15 12:51:53,881 : INFO : EPOCH - 5 : training on 26087311 raw words (25452003 effective words) took 20.5s, 1243222 effective words/s
# 2018-10-15 12:51:53,882 : INFO : training on a 130436555 raw words (127260974 effective words) took 101.6s, 1253180 effective words/s
# Computing time for training the model:108.93075013160706 seconds
# Number of words processed per second: 239485.27820181215
# Word2Vec(vocab=95145, size=300, alpha=0.025)
# Most frequent words In model:  ['said', 'new', 'year', 'like', 'people', 'time', 'years', 'york', 'company', 'percent']
# c:\python3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 2018-10-15 12:51:54,207 : INFO : Pearson correlation coefficient against wordsim353.tsv: 0.6034
# 2018-10-15 12:51:54,208 : INFO : Spearman rank-order correlation coefficient against wordsim353.tsv: 0.6352
# 2018-10-15 12:51:54,208 : INFO : Pairs with unknown words ratio: 4.8%
# c:\python3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: Call to deprecated `accuracy` (Method will be removed in 4.0.0, use self.evaluate_word_analogies() instead).
#   from ipykernel import kernelapp as app
# 2018-10-15 12:51:54,241 : INFO : precomputing L2-norms of word weight vectors
#  similarity evaluation: ((0.6033708946192443, 1.0661791626241528e-34), SpearmanrResult(correlation=0.6352495404801989, pvalue=2.273777221661854e-39), 4.815864022662889)
# 2018-10-15 12:51:55,514 : INFO : capital-common-countries: 60.5% (254/420)
# 2018-10-15 12:51:57,803 : INFO : capital-world: 51.6% (446/864)
# 2018-10-15 12:51:58,144 : INFO : currency: 22.7% (29/128)
# 2018-10-15 12:52:03,400 : INFO : city-in-state: 16.2% (325/2004)
# 2018-10-15 12:52:04,297 : INFO : family: 74.3% (254/342)
# 2018-10-15 12:52:06,589 : INFO : gram1-adjective-to-adverb: 13.7% (119/870)
# 2018-10-15 12:52:08,045 : INFO : gram2-opposite: 18.1% (100/552)
# 2018-10-15 12:52:11,535 : INFO : gram3-comparative: 67.2% (895/1332)
# 2018-10-15 12:52:13,520 : INFO : gram4-superlative: 29.2% (221/756)
# 2018-10-15 12:52:15,229 : INFO : gram5-present-participle: 47.1% (306/650)
# 2018-10-15 12:52:18,632 : INFO : gram6-nationality-adjective: 68.4% (888/1299)
# 2018-10-15 12:52:22,718 : INFO : gram7-past-tense: 55.0% (858/1560)
# 2018-10-15 12:52:25,487 : INFO : gram8-plural: 56.1% (592/1056)
# 2018-10-15 12:52:26,704 : INFO : gram9-plural-verbs: 35.7% (165/462)
# 2018-10-15 12:52:26,705 : INFO : total: 44.3% (5452/12295)
# 2018-10-15 12:52:26,709 : INFO : saving Word2Vec object under D:\data\nyt\word2vecModels\1999, separately None
# 2018-10-15 12:52:26,710 : INFO : storing np array 'vectors' to D:\data\nyt\word2vecModels\1999.wv.vectors.npy
# 2018-10-15 12:52:27,141 : INFO : not storing attribute vectors_norm
# 2018-10-15 12:52:27,142 : INFO : not storing attribute cum_table
# 2018-10-15 12:52:27,349 : INFO : saved D:\data\nyt\word2vecModels\1999
# ----------------------------------------------------
# starting the processing of 1998
# Reading Corpus file and preprocessing time:67.73431754112244 seconds
#  printing Top 2 and last sentences For sanity check
# 0 ['keyshawn', 'johnson', 'said', 'accomplished', 'things', 'set', 'turned', 'pro', 'snaring', 'jets', 'opening', 'pass', 'yards', 'johnson', 'reached', 'receiving', 'yards', 'season', 'making', 'playoffs', 'voted', 'pro', 'bowl', 'week', 'reached', 'percent', 'goals', 'guess', 'said', 'moment', 'like', 'jets', 'clinching', 'division', 'title', 'johnson', 'reflective', 'rookie', 'season', 'thinking', 'locker', 'room', 'today', 'numbskulls', 'got', 'said', 'mind', 'shifting', 'tomorrow', 'night', 'game', 'going', 'biggest', 'sports', 'fan', 'history', 'jets', 'interested', 'jaguars', 'vikings', 'game', 'jaguar', 'loss', 'propels', 'jets', 'week', 'bye', 'playoffs', 'critically', 'important', 'hoping', 'reach', 'super', 'bowl', 'clubs', 'played', 'super', 'bowl', 'enjoying', 'bye', 'week', 'eyes', 'tip', 'defender', 'bills', 'drive', 'ball', 'jets', 'yard', 'line', 'doug', 'flutie', 'looked', 'eric', 'moulds', 'near', 'goal', 'line', 'moulds', 'dangerous', 'receiver', 'covered', 'otis', 'smith', 'ball', 'shoulder', 'smith', 'said', 'play', 'eyes', 'saw', 'eyes', 'big', 'went', 'hand', 'smith', 'hit', 'ball', 'moulds', 'hand', 'moment', 'stopping', 'receiver', 'snaring', 'touchdown', 'play', 'later', 'flutie', 'tipped', 'pass', 'ruled', 'interception', 'victor', 'green', 'starters', 'aaron', 'glenn', 'keith', 'byars', 'missed', 'second', 'consecutive', 'game', 'starters', 'glenn', 'left', 'cornerback', 'sprained', 'ankle', 'byars', 'fullback', 'broken', 'arm', 'catch', 'brady', 'kyle', 'brady', 'career', 'high', 'catch', 'season', 'second', 'quarter', 'wants', 'add', 'personal', 'best', 'think', 'count', 'playoff', 'catches', 'fourth', 'year', 'tight', 'end', 'asked', 'gerald', 'eskenazi']
# 1 ['tampa', 'bay', 'buccaneers', 'win', 'mode', 'realistic', 'playoff', 'hopes', 'alive', 'kept', 'turning', 'great', 'field', 'position', 'instead', 'finally', 'caught', 'fourth', 'quarter', 'short', 'punt', 'fumbled', 'kickoff', 'led', 'quick', 'points', 'waning', 'minutes', 'washington', 'redskins', 'showed', 'resiliency', 'missing', 'norv', 'turner', 'half', 'years', 'coach', 'victory', 'today', 'tampa', 'bay', 'won', 'straight', 'post', 'season', 'chase', 'eliminated', 'playoff', 'contention', 'arizona', 'defeats', 'new', 'orleans', 'giants', 'lose', 'kansas', 'city', 'sunday', 'way', 'tie', 'cardinals', 'giants', 'bucs', 'prevail', 'result', 'clinches', 'playoff', 'berths', 'dallas', 'green', 'bay', 'left', 'lot', 'points', 'field', 'tampa', 'bay', 'defensive', 'tackle', 'warren', 'sapp', 'said', 'game', 'wrapped', 'gift', 'wrapped', 'gave', 'right', 'kind', 'self', 'destructed', 'tampa', 'bay', 'coach', 'tony', 'dungy', 'said', 'everybody', 'disappointed', 'blame', 'thing', 'haven', 'play', 'good', 'solid', 'smart', 'football', 'year', 'mistakes', 'today', 'real', 'big', 'game', 'trent', 'green', 'bootlegged', 'right', 'hit', 'rookie', 'tight', 'end', 'stephen', 'alexander', 'yard', 'touchdown', 'pass', 'minutes', 'seconds', 'play', 'winning', 'score', 'second', 'time', 'weeks', 'redskins', 'come', 'win', 'game', 'fourth', 'quarter', 'previous', 'games', 'turner', 'fourth', 'straight', 'victory', 'sixth', 'games', 'redskins', 'second', 'team', 'national', 'football', 'league', 'history', 'win', 'season', 'starting', 'shows', 'character', 'team', 'tackle', 'shar', 'pourdanesh', 'said', 'buccaneers', 'road', 'season', 'won', 'away', 'game', 'december', 'victory', 'cardinals', 'dec', 'tampa', 'bay', 'appeared', 'game', 'hand', 'solid', 'game', 'defense', 'yards', 'allowed', 'mark', 'fourth', 'quarter', 'bucs', 'lead', 'comfortable', 'offense', 'converted', 'turnovers', 'good', 'punt', 'return', 'field', 'goals', 'game', 'started', 'turn', 'score', 'fourth', 'quarter', 'bad', 'punt', 'tommy', 'barnhardt', 'gave', 'redskins', 'ball', 'plays', 'later', 'cary', 'blanchard', 'kicked', 'yard', 'field', 'goal', 'play', 'ensuing', 'kickoff', 'chris', 'thomas', 'jarred', 'ball', 'loose', 'jacquez', 'green', 'mike', 'sellars', 'recovered', 'setting', 'alexander', 'winning', 'catch', 'redskins', 'defense', 'rest', 'greg', 'jones', 'intercepted', 'trent', 'dilfer', 'pass', 'bucs', 'possession', 'dan', 'wilkinson', 'sack', 'interception', 'darrell', 'green', 'thwarted', 'tampa', 'bay', 'drive', 'final', 'minutes', 'green', 'took', 'error', 'stride', 'saying', 'sees', 'time', 'dungy', 'said', 'replaced', 'green', 'earlier', 'potential', 'return', 'men', 'healthy', 'got', 'better', 'protecting', 'ball', 'dungy', 'said']
# 81660 ['postal', 'service', 'officials', 'testing', 'simple', 'concept', 'tracking', 'late', 'letters', 'sending', 'tiny', 'radio', 'transmitters', 'mail', 'devices', 'allow', 'postal', 'managers', 'track', 'specific', 'pieces', 'mail', 'moving', 'tested', 'houston', 'san', 'francisco', 'northern', 'virginia', 'tried', 'broader', 'basis', 'preliminary', 'reports', 'field', 'managers', 'indicate', 'tracking', 'mail', 'key', 'uncovering', 'bottlenecks', 'consequently', 'improve', 'service', 'classes', 'mail', 'said', 'william', 'dowling', 'service', 'vice', 'president', 'engineering', 'early', 'test', 'postal', 'officials', 'houston', 'perplexed', 'mail', 'moved', 'regularly', 'sorting', 'office', 'transmitter', 'showed', 'item', 'sitting', 'hours', 'day', 'happened', 'finally', 'worker', 'postal', 'operations', 'support', 'problem', 'mail', 'sitting', 'long', 'staging', 'area', 'floor', 'systems', 'based', 'new', 'york', 'began', 'developing', 'transmitters', 'individual', 'pieces', 'mail', 'month', 'postal', 'service', 'announced', 'contract', 'savi', 'technology', 'mountain', 'view', 'calif', 'expand', 'testing', 'include', 'containers', 'mail', 'radios', 'small', 'fit', 'business', 'size', 'envelope', 'radios', 'mailed', 'sensors', 'local', 'regional', 'post', 'offices', 'track', 'said', 'glenn', 'mcdonald', 'manager', 'project', 'tiny', 'radios', 'idle', 'time', 'save', 'batteries', 'mcdonald', 'said', 'periodically', 'turn', 'listen', 'signal', 'sensor', 'hear', 'sensor', 'tell', 'coming', 'going', 'data', 'sensors', 'read', 'local', 'postal', 'managers', 'hookups', 'officials', 'washington', 'headquarters', 'shows', 'interesting', 'processing', 'things', 'invisible', 'mcdonald', 'said', 'interview', 'example', 'said', 'sensors', 'airport', 'mail', 'shipping', 'facilities', 'help', 'officials', 'determine', 'long', 'takes', 'mail', 'airlines', 'mail', 'delayed', 'longer', 'ain', 'babe', 'mcdonald', 'said', 'conveys', 'ownership', 'problems', 'mcdonald', 'said', 'foresees', 'going', 'bottlenecks', 'mail', 'processing', 'tags', 'smaller', 'track', 'priority', 'express', 'mail', 'high', 'value', 'items', 'routine', 'use', 'come', 'sorting', 'centers', 'said', 'dispatching', 'truck', 'loaded', 'mail', 'local', 'post', 'office', 'sensors', 'ping', 'radio', 'tags', 'intended', 'office', 'locating', 'mailbags', 'overlooked', 'fall', 'test', 'expands', 'locations', 'eventually', 'mcdonald', 'wants', 'place', 'nationally', 'postal', 'service', 'spend', 'million', 'phase', 'test']
#  stats about Corpus read from file
# Number of words in corpus: 25252749
# Number of sentences in corpus: 81660
# 2018-10-15 12:53:35,657 : INFO : collecting all words and their counts
# 2018-10-15 12:53:35,658 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-10-15 12:53:36,185 : INFO : PROGRESS: at sentence #10000, processed 3021040 words, keeping 87928 word types
# 2018-10-15 12:53:36,734 : INFO : PROGRESS: at sentence #20000, processed 5983265 words, keeping 116954 word types
# 2018-10-15 12:53:37,311 : INFO : PROGRESS: at sentence #30000, processed 9126375 words, keeping 141323 word types
# 2018-10-15 12:53:37,932 : INFO : PROGRESS: at sentence #40000, processed 12382639 words, keeping 162345 word types
# 2018-10-15 12:53:38,572 : INFO : PROGRESS: at sentence #50000, processed 15532879 words, keeping 189775 word types
# 2018-10-15 12:53:39,181 : INFO : PROGRESS: at sentence #60000, processed 18640325 words, keeping 205634 word types
# 2018-10-15 12:53:39,769 : INFO : PROGRESS: at sentence #70000, processed 21629877 words, keeping 219031 word types
# 2018-10-15 12:53:40,321 : INFO : PROGRESS: at sentence #80000, processed 24757497 words, keeping 232546 word types
# 2018-10-15 12:53:40,421 : INFO : collected 234462 word types from a corpus of 25252749 raw words and 81660 sentences
# 2018-10-15 12:53:40,422 : INFO : Loading a fresh vocabulary
# 2018-10-15 12:53:41,638 : INFO : effective_min_count=5 retains 92789 unique words (39% of original 234462, drops 141673)
# 2018-10-15 12:53:41,639 : INFO : effective_min_count=5 leaves 25017675 word corpus (99% of original 25252749, drops 235074)
# 2018-10-15 12:53:41,858 : INFO : deleting the raw counts dictionary of 234462 items
# 2018-10-15 12:53:41,865 : INFO : sample=0.001 downsamples 7 most-common words
# 2018-10-15 12:53:41,866 : INFO : downsampling leaves estimated 24660455 word corpus (98.6% of prior 25017675)
# 2018-10-15 12:53:42,193 : INFO : estimated required memory for 92789 words and 300 dimensions: 269088100 bytes
# 2018-10-15 12:53:42,194 : INFO : resetting layer weights
# 2018-10-15 12:53:43,079 : INFO : training model with 13 workers on 92789 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=10 window=10
# 2018-10-15 12:53:44,085 : INFO : EPOCH 1 - PROGRESS: at 4.74% examples, 1185290 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:53:45,101 : INFO : EPOCH 1 - PROGRESS: at 10.17% examples, 1223872 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:53:46,113 : INFO : EPOCH 1 - PROGRESS: at 15.61% examples, 1236877 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:53:47,124 : INFO : EPOCH 1 - PROGRESS: at 20.82% examples, 1234661 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:53:48,142 : INFO : EPOCH 1 - PROGRESS: at 26.32% examples, 1240148 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:53:49,142 : INFO : EPOCH 1 - PROGRESS: at 31.09% examples, 1245410 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:53:50,148 : INFO : EPOCH 1 - PROGRESS: at 36.47% examples, 1252596 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:53:51,171 : INFO : EPOCH 1 - PROGRESS: at 41.66% examples, 1252340 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:53:52,187 : INFO : EPOCH 1 - PROGRESS: at 46.29% examples, 1253877 words/s, in_qsize 26, out_qsize 0
# 2018-10-15 12:53:53,191 : INFO : EPOCH 1 - PROGRESS: at 51.38% examples, 1255438 words/s, in_qsize 26, out_qsize 1
# 2018-10-15 12:53:54,191 : INFO : EPOCH 1 - PROGRESS: at 56.38% examples, 1254701 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:53:55,197 : INFO : EPOCH 1 - PROGRESS: at 61.47% examples, 1254692 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:53:56,214 : INFO : EPOCH 1 - PROGRESS: at 66.77% examples, 1256490 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:53:57,217 : INFO : EPOCH 1 - PROGRESS: at 71.72% examples, 1255812 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:53:58,225 : INFO : EPOCH 1 - PROGRESS: at 76.81% examples, 1256280 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 12:53:59,236 : INFO : EPOCH 1 - PROGRESS: at 82.35% examples, 1258155 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:54:00,239 : INFO : EPOCH 1 - PROGRESS: at 87.59% examples, 1257819 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:54:01,255 : INFO : EPOCH 1 - PROGRESS: at 92.69% examples, 1257430 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 12:54:02,262 : INFO : EPOCH 1 - PROGRESS: at 97.79% examples, 1256888 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:54:02,605 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2018-10-15 12:54:02,616 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2018-10-15 12:54:02,617 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2018-10-15 12:54:02,617 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2018-10-15 12:54:02,618 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2018-10-15 12:54:02,644 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2018-10-15 12:54:02,647 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2018-10-15 12:54:02,649 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-10-15 12:54:02,651 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-10-15 12:54:02,661 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-15 12:54:02,664 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-15 12:54:02,667 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-15 12:54:02,669 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-15 12:54:02,670 : INFO : EPOCH - 1 : training on 25252749 raw words (24652231 effective words) took 19.6s, 1258727 effective words/s
# 2018-10-15 12:54:03,674 : INFO : EPOCH 2 - PROGRESS: at 4.74% examples, 1186019 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:54:04,680 : INFO : EPOCH 2 - PROGRESS: at 10.12% examples, 1224966 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 12:54:05,691 : INFO : EPOCH 2 - PROGRESS: at 15.54% examples, 1235346 words/s, in_qsize 26, out_qsize 2
# ...
# 2018-10-15 13:35:03,655 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-15 13:35:03,663 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-15 13:35:03,673 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-15 13:35:03,673 : INFO : EPOCH - 1 : training on 22593750 raw words (22047564 effective words) took 17.4s, 1267986 effective words/s
# 2018-10-15 13:35:04,692 : INFO : EPOCH 2 - PROGRESS: at 6.01% examples, 1186313 words/s, in_qsize 22, out_qsize 3
# 2018-10-15 13:35:05,693 : INFO : EPOCH 2 - PROGRESS: at 11.94% examples, 1234911 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 13:35:06,700 : INFO : EPOCH 2 - PROGRESS: at 16.95% examples, 1239892 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:35:07,710 : INFO : EPOCH 2 - PROGRESS: at 22.77% examples, 1242824 words/s, in_qsize 26, out_qsize 1
# 2018-10-15 13:35:08,719 : INFO : EPOCH 2 - PROGRESS: at 28.76% examples, 1248696 words/s, in_qsize 25, out_qsize 2
# 2018-10-15 13:35:09,719 : INFO : EPOCH 2 - PROGRESS: at 34.35% examples, 1250665 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:10,729 : INFO : EPOCH 2 - PROGRESS: at 40.00% examples, 1253755 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 13:35:11,738 : INFO : EPOCH 2 - PROGRESS: at 45.38% examples, 1251497 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 13:35:12,738 : INFO : EPOCH 2 - PROGRESS: at 51.01% examples, 1249846 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:13,760 : INFO : EPOCH 2 - PROGRESS: at 56.83% examples, 1250533 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:14,760 : INFO : EPOCH 2 - PROGRESS: at 62.48% examples, 1252407 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:15,778 : INFO : EPOCH 2 - PROGRESS: at 68.19% examples, 1251911 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:35:16,784 : INFO : EPOCH 2 - PROGRESS: at 73.94% examples, 1250869 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:35:17,807 : INFO : EPOCH 2 - PROGRESS: at 79.85% examples, 1248049 words/s, in_qsize 26, out_qsize 1
# 2018-10-15 13:35:18,826 : INFO : EPOCH 2 - PROGRESS: at 85.21% examples, 1246266 words/s, in_qsize 26, out_qsize 2
# 2018-10-15 13:35:19,831 : INFO : EPOCH 2 - PROGRESS: at 91.51% examples, 1246845 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:20,854 : INFO : EPOCH 2 - PROGRESS: at 96.80% examples, 1241699 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:21,355 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2018-10-15 13:35:21,357 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2018-10-15 13:35:21,375 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2018-10-15 13:35:21,376 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2018-10-15 13:35:21,377 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2018-10-15 13:35:21,399 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2018-10-15 13:35:21,405 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2018-10-15 13:35:21,408 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-10-15 13:35:21,410 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-10-15 13:35:21,422 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-15 13:35:21,423 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-15 13:35:21,426 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-15 13:35:21,435 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-15 13:35:21,436 : INFO : EPOCH - 2 : training on 22593750 raw words (22047590 effective words) took 17.8s, 1241515 effective words/s
# 2018-10-15 13:35:22,449 : INFO : EPOCH 3 - PROGRESS: at 5.71% examples, 1136564 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 13:35:23,452 : INFO : EPOCH 3 - PROGRESS: at 11.32% examples, 1166871 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:24,469 : INFO : EPOCH 3 - PROGRESS: at 16.11% examples, 1171540 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:25,469 : INFO : EPOCH 3 - PROGRESS: at 21.16% examples, 1168314 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:35:26,481 : INFO : EPOCH 3 - PROGRESS: at 27.09% examples, 1175729 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:27,481 : INFO : EPOCH 3 - PROGRESS: at 31.73% examples, 1160611 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:28,489 : INFO : EPOCH 3 - PROGRESS: at 37.80% examples, 1170932 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:29,499 : INFO : EPOCH 3 - PROGRESS: at 42.25% examples, 1175016 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:30,513 : INFO : EPOCH 3 - PROGRESS: at 48.24% examples, 1181025 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 13:35:31,522 : INFO : EPOCH 3 - PROGRESS: at 53.69% examples, 1182142 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:32,525 : INFO : EPOCH 3 - PROGRESS: at 59.20% examples, 1188039 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:33,537 : INFO : EPOCH 3 - PROGRESS: at 65.12% examples, 1191718 words/s, in_qsize 25, out_qsize 1
# 2018-10-15 13:35:34,549 : INFO : EPOCH 3 - PROGRESS: at 70.73% examples, 1196601 words/s, in_qsize 26, out_qsize 2
# 2018-10-15 13:35:35,549 : INFO : EPOCH 3 - PROGRESS: at 76.40% examples, 1200404 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:35:36,564 : INFO : EPOCH 3 - PROGRESS: at 82.49% examples, 1203883 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:35:37,584 : INFO : EPOCH 3 - PROGRESS: at 88.08% examples, 1206658 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:35:38,593 : INFO : EPOCH 3 - PROGRESS: at 94.55% examples, 1209827 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:35:39,520 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2018-10-15 13:35:39,529 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2018-10-15 13:35:39,530 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2018-10-15 13:35:39,532 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2018-10-15 13:35:39,562 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2018-10-15 13:35:39,563 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2018-10-15 13:35:39,567 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2018-10-15 13:35:39,568 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-10-15 13:35:39,569 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-10-15 13:35:39,582 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-15 13:35:39,585 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-15 13:35:39,586 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-15 13:35:39,587 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-15 13:35:39,588 : INFO : EPOCH - 3 : training on 22593750 raw words (22047174 effective words) took 18.1s, 1214977 effective words/s
# 2018-10-15 13:35:40,599 : INFO : EPOCH 4 - PROGRESS: at 6.04% examples, 1204549 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:35:41,613 : INFO : EPOCH 4 - PROGRESS: at 11.94% examples, 1231594 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:42,618 : INFO : EPOCH 4 - PROGRESS: at 16.95% examples, 1238469 words/s, in_qsize 26, out_qsize 2
# 2018-10-15 13:35:43,623 : INFO : EPOCH 4 - PROGRESS: at 22.65% examples, 1238709 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:35:44,625 : INFO : EPOCH 4 - PROGRESS: at 28.52% examples, 1241132 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 13:35:45,627 : INFO : EPOCH 4 - PROGRESS: at 34.12% examples, 1244138 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:46,646 : INFO : EPOCH 4 - PROGRESS: at 39.54% examples, 1235999 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 13:35:47,660 : INFO : EPOCH 4 - PROGRESS: at 44.71% examples, 1232864 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:35:48,666 : INFO : EPOCH 4 - PROGRESS: at 50.19% examples, 1230130 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 13:35:49,677 : INFO : EPOCH 4 - PROGRESS: at 55.95% examples, 1231480 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:50,684 : INFO : EPOCH 4 - PROGRESS: at 61.52% examples, 1233305 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:35:51,697 : INFO : EPOCH 4 - PROGRESS: at 67.41% examples, 1234457 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:52,703 : INFO : EPOCH 4 - PROGRESS: at 73.06% examples, 1233997 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 13:35:53,718 : INFO : EPOCH 4 - PROGRESS: at 78.97% examples, 1235564 words/s, in_qsize 26, out_qsize 1
# 2018-10-15 13:35:54,728 : INFO : EPOCH 4 - PROGRESS: at 84.58% examples, 1236628 words/s, in_qsize 22, out_qsize 3
# 2018-10-15 13:35:55,736 : INFO : EPOCH 4 - PROGRESS: at 90.72% examples, 1238056 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:35:56,747 : INFO : EPOCH 4 - PROGRESS: at 96.58% examples, 1239480 words/s, in_qsize 26, out_qsize 0
# 2018-10-15 13:35:57,290 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2018-10-15 13:35:57,299 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2018-10-15 13:35:57,299 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2018-10-15 13:35:57,303 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2018-10-15 13:35:57,307 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2018-10-15 13:35:57,317 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2018-10-15 13:35:57,331 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2018-10-15 13:35:57,336 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-10-15 13:35:57,337 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-10-15 13:35:57,337 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-15 13:35:57,349 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-15 13:35:57,350 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-15 13:35:57,352 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-15 13:35:57,353 : INFO : EPOCH - 4 : training on 22593750 raw words (22047675 effective words) took 17.8s, 1241395 effective words/s
# 2018-10-15 13:35:58,370 : INFO : EPOCH 5 - PROGRESS: at 6.12% examples, 1207062 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:35:59,379 : INFO : EPOCH 5 - PROGRESS: at 12.02% examples, 1239783 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:36:00,381 : INFO : EPOCH 5 - PROGRESS: at 16.92% examples, 1236091 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:36:01,387 : INFO : EPOCH 5 - PROGRESS: at 22.80% examples, 1245970 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:36:02,392 : INFO : EPOCH 5 - PROGRESS: at 28.56% examples, 1242414 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 13:36:03,404 : INFO : EPOCH 5 - PROGRESS: at 34.20% examples, 1244835 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:36:04,417 : INFO : EPOCH 5 - PROGRESS: at 39.79% examples, 1244169 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:36:05,423 : INFO : EPOCH 5 - PROGRESS: at 45.18% examples, 1245867 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:36:06,441 : INFO : EPOCH 5 - PROGRESS: at 50.81% examples, 1242480 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:36:07,445 : INFO : EPOCH 5 - PROGRESS: at 56.51% examples, 1243245 words/s, in_qsize 25, out_qsize 0
# 2018-10-15 13:36:08,460 : INFO : EPOCH 5 - PROGRESS: at 62.05% examples, 1242441 words/s, in_qsize 24, out_qsize 1
# 2018-10-15 13:36:09,471 : INFO : EPOCH 5 - PROGRESS: at 67.88% examples, 1242838 words/s, in_qsize 22, out_qsize 3
# 2018-10-15 13:36:10,483 : INFO : EPOCH 5 - PROGRESS: at 73.62% examples, 1243186 words/s, in_qsize 26, out_qsize 2
# 2018-10-15 13:36:11,489 : INFO : EPOCH 5 - PROGRESS: at 79.54% examples, 1243101 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 13:36:12,492 : INFO : EPOCH 5 - PROGRESS: at 84.97% examples, 1242956 words/s, in_qsize 26, out_qsize 0
# 2018-10-15 13:36:13,518 : INFO : EPOCH 5 - PROGRESS: at 91.16% examples, 1242113 words/s, in_qsize 23, out_qsize 2
# 2018-10-15 13:36:14,522 : INFO : EPOCH 5 - PROGRESS: at 96.79% examples, 1242538 words/s, in_qsize 26, out_qsize 0
# 2018-10-15 13:36:15,017 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2018-10-15 13:36:15,020 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2018-10-15 13:36:15,030 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2018-10-15 13:36:15,035 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2018-10-15 13:36:15,037 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2018-10-15 13:36:15,043 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2018-10-15 13:36:15,048 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2018-10-15 13:36:15,053 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-10-15 13:36:15,061 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-10-15 13:36:15,062 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-15 13:36:15,071 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-15 13:36:15,073 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-15 13:36:15,081 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-15 13:36:15,082 : INFO : EPOCH - 5 : training on 22593750 raw words (22047412 effective words) took 17.7s, 1243896 effective words/s
# 2018-10-15 13:36:15,083 : INFO : training on a 112968750 raw words (110237415 effective words) took 88.8s, 1241398 effective words/s
# Computing time for training the model:94.84030890464783 seconds
# Number of words processed per second: 238229.40120023958
# Word2Vec(vocab=85042, size=300, alpha=0.025)
# Most frequent words In model:  ['said', 'new', 'year', 'years', 'percent', 'time', 'york', 'people', 'state', 'million']
# 2018-10-15 13:36:15,857 : INFO : Pearson correlation coefficient against wordsim353.tsv: 0.5905
# 2018-10-15 13:36:15,858 : INFO : Spearman rank-order correlation coefficient against wordsim353.tsv: 0.6088
# 2018-10-15 13:36:15,859 : INFO : Pairs with unknown words ratio: 4.5%
# 2018-10-15 13:36:15,899 : INFO : precomputing L2-norms of word weight vectors
#  similarity evaluation: ((0.5904819378166569, 4.756788310271214e-33), SpearmanrResult(correlation=0.6088101209747272, pvalue=1.468680064795531e-35), 4.53257790368272)
# 2018-10-15 13:36:16,958 : INFO : capital-common-countries: 57.0% (195/342)
# 2018-10-15 13:36:19,474 : INFO : capital-world: 55.5% (526/947)
# 2018-10-15 13:36:19,660 : INFO : currency: 7.4% (5/68)
# 2018-10-15 13:36:25,343 : INFO : city-in-state: 25.7% (550/2144)
# 2018-10-15 13:36:26,248 : INFO : family: 67.0% (229/342)
# 2018-10-15 13:36:28,554 : INFO : gram1-adjective-to-adverb: 14.5% (126/870)
# 2018-10-15 13:36:30,276 : INFO : gram2-opposite: 16.8% (109/650)
# 2018-10-15 13:36:33,817 : INFO : gram3-comparative: 63.9% (851/1332)
# 2018-10-15 13:36:35,678 : INFO : gram4-superlative: 34.0% (239/702)
# 2018-10-15 13:36:37,404 : INFO : gram5-present-participle: 38.0% (247/650)
# 2018-10-15 13:36:40,309 : INFO : gram6-nationality-adjective: 84.7% (928/1095)
# 2018-10-15 13:36:44,442 : INFO : gram7-past-tense: 50.5% (788/1560)
# 2018-10-15 13:36:47,404 : INFO : gram8-plural: 50.1% (562/1122)
# 2018-10-15 13:36:48,744 : INFO : gram9-plural-verbs: 31.4% (159/506)
# 2018-10-15 13:36:48,745 : INFO : total: 44.7% (5514/12330)
# 2018-10-15 13:36:48,751 : INFO : saving Word2Vec object under D:\data\nyt\word2vecModels\1985, separately None
# 2018-10-15 13:36:48,751 : INFO : storing np array 'vectors' to D:\data\nyt\word2vecModels\1985.wv.vectors.npy
# 2018-10-15 13:36:49,122 : INFO : not storing attribute vectors_norm
# 2018-10-15 13:36:49,123 : INFO : not storing attribute cum_table
# 2018-10-15 13:36:49,308 : INFO : saved D:\data\nyt\word2vecModels\1985
# ----------------------------------------------------

# %% [markdown]
# ## Sanity check to make sure models have been saved

# %%
#Sanity check to make sure models have been saved
from gensim.models.word2vec import Word2Vec
import gensim

year = '2002'
print(year)
filePath = os.path.join(outputPath, year)
model = gensim.models.Word2Vec.load(filePath) # you can continue training with the loaded model!
print(model)
model.wv.index2word[:10]
# Out:
# 2018-10-15 11:55:10,585 : INFO : loading Word2Vec object from D:\data\nyt\word2vecModels\2002
# 2002
# 2018-10-15 11:55:11,227 : INFO : loading wv recursively from D:\data\nyt\word2vecModels\2002.wv.* with mmap=None
# 2018-10-15 11:55:11,228 : INFO : loading vectors from D:\data\nyt\word2vecModels\2002.wv.vectors.npy with mmap=None
# 2018-10-15 11:55:11,285 : INFO : setting ignored attribute vectors_norm to None
# 2018-10-15 11:55:11,286 : INFO : loading vocabulary recursively from D:\data\nyt\word2vecModels\2002.vocabulary.* with mmap=None
# 2018-10-15 11:55:11,287 : INFO : loading trainables recursively from D:\data\nyt\word2vecModels\2002.trainables.* with mmap=None
# 2018-10-15 11:55:11,287 : INFO : setting ignored attribute cum_table to None
# 2018-10-15 11:55:11,288 : INFO : loaded D:\data\nyt\word2vecModels\2002
# Word2Vec(vocab=97437, size=300, alpha=0.025)
# ['said',
#  'new',
#  'year',
#  'like',
#  'people',
#  'time',
#  'years',
#  'company',
#  'york',
#  'percent']

# %%
model.wv.most_similar('man')
# Out:
# c:\python3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('woman', 0.657943069934845),
#  ('policeman', 0.5610487461090088),
#  ('gentleman', 0.5473320484161377),
#  ('men', 0.5011500120162964),
#  ('guy', 0.4981834292411804),
#  ('balding', 0.4937747120857239),
#  ('gruff', 0.4927574396133423),
#  ('assailant', 0.4926893711090088),
#  ('drifter', 0.49006587266921997),
#  ('lover', 0.4891093969345093)]

# %%
def similarityMetricsAlternative(model):
    #listDiversityTerms=['diversity', 'diverse']
    listDiversityTerms=['diversity']
    
     
    listDemographicsTermsUpdated=[w for w in listDemographicsTerms if w in model.wv.vocab]
    listIntellectualTermsUpdated=[w for w in listIntellectualTerms if w in model.wv.vocab]
    
    similarityDemographics = model.wv.n_similarity(listDiversityTerms,listDemographicsTermsUpdated)
    similarityIntellectual = model.wv.n_similarity(listDiversityTerms,listIntellectualTermsUpdated)
    return (similarityDemographics,similarityIntellectual)

# %%
from commonVariables import listDemographicsTerms, listIntellectualTerms
similarityDemographics2, similarityIntellectual2= similarityMetricsAlternative(model)
similarityDemographics2,similarityIntellectual2
# Out:
# (0.3289945841610287, 0.09222000420760601)
